# %% [markdown]
# <a href="https://colab.research.google.com/github/ethan060626/generative_ai/blob/main/week8_hw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![擷取1.PNG](data:image/png;base64,...)![擷取2.PNG](data:image/png;base64,...)![擷取4.PNG](data:image/png;base64,...)![擷取5.PNG](data:image/png;base64,...)![擷取3.PNG](data:image/png;base64,...)

# %% [markdown]
# ![擷取.PNG](data:image/png;base64,...)
