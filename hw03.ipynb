# %% [markdown]
# <a href="https://colab.research.google.com/github/ethan060626/generative_ai/blob/main/hw03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [This X Does Not Exist](https://thisxdoesnotexist.com/)
#
#
#
#
# ![下載.jpg](data:image/jpeg;base64,...)![下載 (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# [pix2pix](https://affinelayer.com/pixsrv/)
#
#
#
# ![pix2pix.png](data:image/png;base64,...)
