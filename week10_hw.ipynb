# %% [markdown]
# <a href="https://colab.research.google.com/github/ethan060626/generative_ai/blob/main/week10_hw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 風格: 現實
# 輸入: A realistic-style image of a cat wearing a crown, sitting on a throne inside a castle.
#   ![1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 風格: 現實
# 輸入: A photorealistic image of a dog wearing sunglasses, confidently driving a red sports car on a sunny day.
# ![2.jpg](data:image/jpeg;base64,...)
