# %% [markdown]
# <a href="https://colab.research.google.com/github/ethan060626/generative_ai/blob/main/hw04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 作業四

# %% [markdown]
# # Q:你對太空人在2017依靠作弊拿到冠軍有甚麼看法?

# %% [markdown]
# # ChatGPT-4o:
# ![擷取.PNG](data:image/png;base64,...)

# %% [markdown]
# # Claude 3.7:
# ![擷取1.PNG](data:image/png;base64,...)

# %% [markdown]
# #結論
# 經過測試後，我發現chatgpt更喜歡用條列式表達，比較容易閱讀，而且chatgpt在最後一句反問我的看法，比起claude更有在和一個真人聊天的感覺。
